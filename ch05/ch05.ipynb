# %%
def factorial(n):
    """returns n!"""

    return 1 if n < 2 else n * factorial(n - 1)

# %%
factorial(42)
# Out:
# 1405006117752879898543142606244511569936384000000000

# %%
factorial.__doc__
# Out:
# 'returns n!'

# %%
type(factorial)
# Out:
# function

# %%
fact = factorial
fact
# Out:
# <function __main__.factorial(n)>

# %%
fact(5)
# Out:
# 120

# %%
map(factorial, range(11))

# %%
list(map(factorial, range(11)))
# Out:
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]

# %% [markdown]
# # High-Order Functions

# %%
fruits = ['strawberry', 'fig', 'apple', 'cherry', 'raspberry', 'banana']
sorted(fruits, key=len)
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspberry', 'strawberry']

# %%
print(list(reversed("abcd")))
# Out:
# ['d', 'c', 'b', 'a']

# %%
''.join(list(reversed("abcd")))
# Out:
# 'dcba'

# %%
def reverse(word):
    return word[::-1]   
reverse('abcd')
# Out:
# 'dcba'

# %% [markdown]
# # Modern Replacements for map, filter, and reduce

# %%
list(map(fact, range(6)))
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
[fact(n) for n in range(6)]
# Out:
# [1, 1, 2, 6, 24, 120]

# %%
[(n, factorial(n)) for n in range(6) if n % 2]
# Out:
# [(1, 1), (3, 6), (5, 120)]

# %%
list(map(factorial, filter(lambda n: n % 2, range(6))))
# Out:
# [1, 6, 120]

# %%
[factorial(n) for n in range(6) if n % 2]
# Out:
# [1, 6, 120]

# %%
from functools import reduce
from operator import add
reduce(add, range(100))
# Out:
# 4950

# %%
sum(range(100))
# Out:
# 4950

# %%
import random

class BingoCage:
    def __init__(self, items):
        self._items = list(items)
        random.shuffle(self._items)

    def pick(self):
        try:
            return self._items.pop()
        except IndexError:
            raise LookupError('pick from empty BingoCage')
        
    def __call__(self):
        return self.pick()

# %%
bingo = BingoCage(range(3))
bingo._items
# Out:
# [2, 0, 1]

# %%
print(bingo.pick())
bingo._items
# Out:
# 1
# [2, 0]

# %%
bingo()
# Out:
# 0

# %%
bingo()
# Out:
# 2

# %%
bingo()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 10, in BingoCage.pick(self)
#       9 try:
# ---> 10     return self._items.pop()
#      11 except IndexError:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 bingo()
#
# Cell In[33], line 15, in BingoCage.__call__(self)
#      14 def __call__(self):
# ---> 15     return self.pick()
#
# Cell In[33], line 12, in BingoCage.pick(self)
#      10     return self._items.pop()
#      11 except IndexError:
# ---> 12     raise LookupError('pick from empty BingoCage')
#
# LookupError: pick from empty BingoCage

# %%
bingo._items
# Out:
# []

# %%
dir(factorial)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']

# %%
class C: 
    pass
obj = C()
def func(): 
    pass
sorted(set(dir(func)) - set(dir(obj)))
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__get__',
#  '__globals__',
#  '__kwdefaults__',
#  '__name__',
#  '__qualname__',
#  '__type_params__']
