# %%
print("Hello, ch02!")
# Out:
# Hello, ch02!

# %% [markdown]
# # List Comprehensions

# %%
symbols = "ㄱㄴㄷㄹㅁ"
codes = []
for symbol in symbols:
    codes.append(ord(symbol))
codes
# Out:
# [12593, 12596, 12599, 12601, 12609]

# %%
symbols = "ㄱㄴㄷㄹㅁ"
codes = [ord(symbol) for symbol in symbols]
codes
# Out:
# [12593, 12596, 12599, 12601, 12609]

# %%
symbols = "ㄱㄴㄷㄹㅁ"
beyond_ascii = [ord(symbol) for symbol in symbols if ord(symbol) > 127]
beyond_ascii
# Out:
# [12593, 12596, 12599, 12601, 12609]

# %% [markdown]
# # Listcomps, map and filter

# %%
symbols = "ㄱㄴㄷㄹㅁ"
beyond_ascii = list(filter(lambda c: c > 127, map(ord, symbols)))
beyond_ascii
# Out:
# [12593, 12596, 12599, 12601, 12609]

# %% [markdown]
# # Cartesian Products

# %%
colors = ['black', 'white']
sizes = ['S', 'M', 'L']
tshirts = [(color, size) for color in colors for size in sizes]
tshirts
# Out:
# [('black', 'S'),
#  ('black', 'M'),
#  ('black', 'L'),
#  ('white', 'S'),
#  ('white', 'M'),
#  ('white', 'L')]

# %%
for color in colors:
    for size in sizes:
        print((color, size))
# Out:
# ('black', 'S')
# ('black', 'M')
# ('black', 'L')
# ('white', 'S')
# ('white', 'M')
# ('white', 'L')

# %%
tshirts = [(color, size) for size in sizes for color in colors]
tshirts
# Out:
# [('black', 'S'),
#  ('white', 'S'),
#  ('black', 'M'),
#  ('white', 'M'),
#  ('black', 'L'),
#  ('white', 'L')]

# %% [markdown]
# # Generator Expression

# %%
symbols = "ㄱㄴㄷㄹㅁ"
tuple(ord(symbol) for symbol in symbols)
# Out:
# (12593, 12596, 12599, 12601, 12609)

# %%
import array
array.array('I', (ord(symbol) for symbol in symbols))
# Out:
# array('I', [12593, 12596, 12599, 12601, 12609])

# %%
colors = ['black', 'white']
sizes = ['S', 'M', 'L']
for tshirt in (f"{color} {size}" for color in colors for size in sizes):
    print(tshirt)
# Out:
# black S
# black M
# black L
# white S
# white M
# white L

# %% [markdown]
# # Tuple as Records

# %%
lax_coordinates = (33.9425, -118.408056)
city, year, pop, chg, area = ('Tokyo', 2003, 32450, 0.66, 8014)
traveler_ids = [('USA', '31195855'), ('BRA', 'CE342567'), ('ESP', 'XDA205855')]
for passport in sorted(traveler_ids):
    #print('%s/%s' % passport)
    print(f'{passport[0]}/{passport[1]}')
for country, _ in traveler_ids:
    print(country)
# Out:
# BRA/CE342567
# ESP/XDA205855
# USA/31195855
# USA
# BRA
# ESP

# %% [markdown]
# # Tuple Unpacking

# %%
lax_coordinates = (33.9425, -118.408056)
latitude, longitude = lax_coordinates
print(latitude)
print(longitude)
# Out:
# 33.9425
# -118.408056

# %%
divmod(20, 8)
# Out:
# (2, 4)

# %%
t = (20, 8)
divmod(*t)
# Out:
# (2, 4)

# %%
quotient, remainder = divmod(*t)
quotient, remainder
# Out:
# (2, 4)

# %%
import os
os.path.split('/home/luciano/.ssh/idrsa.pub') # split the path into a pair (head, tail) where tail is the last pathname component and head is everything leading up to that.
# Out:
# ('/home/luciano/.ssh', 'idrsa.pub')

# %%
_, filename = os.path.split('/home/luciano/.ssh/id_rsa.pub')
filename
# Out:
# 'id_rsa.pub'

# %% [markdown]
# ## Using * to grab excell items

# %%
a, b, *rest = range(5)
a, b, rest
# Out:
# (0, 1, [2, 3, 4])

# %%
a, b, *rest = range(3)
a, b, rest
# Out:
# (0, 1, [2])

# %%
a, b, *rest = range(2)
a, b, rest
# Out:
# (0, 1, [])

# %%
metro_areas = [
    ('Tokyo', 'JP', 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', 'IN', 21.935, (28.613889, 77.208889)),
    ('Shanghai', 'CN', 25.582, (31.216667, 121.5)),
    ('Sao Paulo', 'BR', 21.650, (-23.547778, -46.635833)),  
    ('Mexico City', 'MX', 20.142, (19.433333, -99.133333)),
]
for name, cc, pop, (latitude, longitude) in metro_areas:
    print(f'{name:15} | {cc} | {pop:9.3f} | {latitude:6.2f}, {longitude:6.2f}') if longitude > 0 else print(f'{name:15} | {cc} | {pop:9.3f} | {latitude:6.2f}, {longitude:6.2f} <')
# Out:
# Tokyo           | JP |    36.933 |  35.69, 139.69
# Delhi NCR       | IN |    21.935 |  28.61,  77.21
# Shanghai        | CN |    25.582 |  31.22, 121.50
# Sao Paulo       | BR |    21.650 | -23.55, -46.64 <
# Mexico City     | MX |    20.142 |  19.43, -99.13 <

# %% [markdown]
# # Named Tuples

# %%
from collections import namedtuple
City = namedtuple('City', 'name country population coordinates')
tokyo = City(name='Tokyo', country='JP', population=36.933, coordinates=(35.689722, 139.691667))
tokyo
# Out:
# City(name='Tokyo', country='JP', population=36.933, coordinates=(35.689722, 139.691667))

# %%
print(tokyo.population)
print(tokyo.coordinates)
print(tokyo.coordinates[0])
print(tokyo.coordinates[1])
print(tokyo[1])
# Out:
# 36.933
# (35.689722, 139.691667)
# 35.689722
# 139.691667
# JP

# %%
City._fields
# Out:
# ('name', 'country', 'population', 'coordinates')

# %% [markdown]
# # Slicing
# seq[start:stop:step]

# %%
l = [10, 20, 30, 40, 50, 60]
l[:2]
# Out:
# [10, 20]

# %%
l[2:]
# Out:
# [30, 40, 50, 60]

# %%
l[:3]
# Out:
# [10, 20, 30]

# %%
l[3:]
# Out:
# [40, 50, 60]

# %%
s = 'bicycle'
s[::3]
# Out:
# 'bye'

# %%
s[::-1]
# Out:
# 'elcycib'

# %%
s[::-2]
# Out:
# 'eccb'

# %%
invoice = """
0.....6.................................40........52...55........
1909  Pimoroni PiBrella                     $17.50    3    $52.50
1489  6mm Tactile Switch x20                 $4.95    2     $9.90
1510  Panavise Jr. - PV-PV-201              $28.00    1    $28.00
1601  PiTFT Mini Kit 320x240                $34.95    1    $34.95
""" 
SKU = slice(0, 6)
DESCRIPTION = slice(6, 40)
UNIT_PRICE = slice(40, 52)
QUANTITY = slice(52, 55)
ITEM_TOTAL = slice(55, None)
line_items = invoice.split('\n')[2:]
line_items
# Out:
# ['1909  Pimoroni PiBrella                     $17.50    3    $52.50',
#  '1489  6mm Tactile Switch x20                $4.95     2     $9.90',
#  '1510  Panavise Jr. - PV-PV-201              $28.00    1    $28.00',
#  '1601  PiTFT Mini Kit 320x240                $34.95    1    $34.95',
#  '']

# %%
for item in line_items:
    print(item[UNIT_PRICE], item[DESCRIPTION])
# Out:
#     $17.50   Pimoroni PiBrella
#     $4.95    6mm Tactile Switch x20
#     $28.00   Panavise Jr. - PV-PV-201
#     $34.95   PiTFT Mini Kit 320x240
